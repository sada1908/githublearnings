# %% [markdown]
# <a href="https://colab.research.google.com/github/sada1908/githublearnings/blob/main/Final_Auto_Port_Handling_snr_1606.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
import zipfile
import os
from sklearn.model_selection import train_test_split

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.preprocessing import image

# %%
from tensorflow.keras.layers import GlobalAveragePooling2D

# %%
import cv2
from google.colab.patches import cv2_imshow

# %%
import pathlib

# %%
from sklearn.metrics import classification_report

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# %%
from imblearn.over_sampling import SMOTE

# %%
from sklearn.preprocessing import LabelEncoder

# %%
# !unzip -q /content/drive/MyDrive/Automating_Port_Operations_dataset.zip -d /content1/

# %%
# !ls /content1/Automating_Port_Operations_dataset/
# Out:
# buoy  cruise_ship  ferry_boat  freight_boat  gondola  inflatable_boat  kayak  paper_boat  sailboat

# %%
my_img_dir = pathlib.Path('/content1/Automating_Port_Operations_dataset/')

# %%
my_img_files = list(my_img_dir.glob(r'*/*'))

# %%
my_img_files[0]
# Out:
# PosixPath('/content1/Automating_Port_Operations_dataset/gondola/148.jpg')

# %%
labels =[]
labels = [pathlib.Path(path).parent.name for path in my_img_files]

# %%
len(my_img_files),len(labels)
# Out:
# (1162, 1162)

# %%
my_img_df = pd.DataFrame(my_img_files, columns=['image_path'])
my_img_df['label'] = labels

# %%
my_img_df['image_path'] = my_img_df['image_path'].astype(str)

# %%
my_img_df.head(np.random.randint(10))
# Out:
#                                           image_path    label
# 0  /content1/Automating_Port_Operations_dataset/g...  gondola
# 1  /content1/Automating_Port_Operations_dataset/g...  gondola
# 2  /content1/Automating_Port_Operations_dataset/g...  gondola
# 3  /content1/Automating_Port_Operations_dataset/g...  gondola
# 4  /content1/Automating_Port_Operations_dataset/g...  gondola
# 5  /content1/Automating_Port_Operations_dataset/g...  gondola
# 6  /content1/Automating_Port_Operations_dataset/g...  gondola

# %%
my_img_df['label'].value_counts()
# Out:
# label
# sailboat           389
# kayak              203
# gondola            193
# cruise_ship        191
# ferry_boat          63
# buoy                53
# paper_boat          31
# freight_boat        23
# inflatable_boat     16
# Name: count, dtype: int64

# %%
X = my_img_df['image_path']
y = my_img_df['label']

# %%
label_encoder = LabelEncoder()
X_encoded = label_encoder.fit_transform(X)

# %%
X_encoded
# Out:
# array([384, 349, 411, ..., 290, 276, 301])

# %%
# Label encode the target variable
label_encoder_y = LabelEncoder()
y_encoded = label_encoder_y.fit_transform(y)

# %%
# Apply SMOTE to balance the dataset
smote = SMOTE(random_state=42)
X_new, y_new = smote.fit_resample(X_encoded.reshape(-1, 1), y_encoded)

# %%
X_inv = label_encoder.inverse_transform(X_new)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_label.py:155: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
y_inv = label_encoder_y.inverse_transform(y_new)

# %%
new_img_df = pd.DataFrame({'image_path': X_inv, 'label': y_inv})

# %%
new_img_df['label'].value_counts()
# Out:
# label
# gondola            389
# sailboat           389
# paper_boat         389
# kayak              389
# freight_boat       389
# inflatable_boat    389
# cruise_ship        389
# buoy               389
# ferry_boat         389
# Name: count, dtype: int64

# %%
new_img_df.sample(25)
# Out:
#                                              image_path            label
# 226   /content1/Automating_Port_Operations_dataset/s...         sailboat
# 1428  /content1/Automating_Port_Operations_dataset/b...             buoy
# 11    /content1/Automating_Port_Operations_dataset/g...          gondola
# 171   /content1/Automating_Port_Operations_dataset/g...          gondola
# 1387  /content1/Automating_Port_Operations_dataset/b...             buoy
# 2611  /content1/Automating_Port_Operations_dataset/i...  inflatable_boat
# 1939  /content1/Automating_Port_Operations_dataset/f...       ferry_boat
# 715   /content1/Automating_Port_Operations_dataset/k...            kayak
# 1250  /content1/Automating_Port_Operations_dataset/b...             buoy
# 620   /content1/Automating_Port_Operations_dataset/k...            kayak
# 1885  /content1/Automating_Port_Operations_dataset/f...       ferry_boat
# 2218  /content1/Automating_Port_Operations_dataset/f...     freight_boat
# 145   /content1/Automating_Port_Operations_dataset/g...          gondola
# 3037  /content1/Automating_Port_Operations_dataset/k...            kayak
# 2437  /content1/Automating_Port_Operations_dataset/g...          gondola
# 890   /content1/Automating_Port_Operations_dataset/c...      cruise_ship
# 1148  /content1/Automating_Port_Operations_dataset/f...       ferry_boat
# 1876  /content1/Automating_Port_Operations_dataset/f...       ferry_boat
# 1409  /content1/Automating_Port_Operations_dataset/b...             buoy
# 2966  /content1/Automating_Port_Operations_dataset/k...            kayak
# 37    /content1/Automating_Port_Operations_dataset/g...          gondola
# 766   /content1/Automating_Port_Operations_dataset/k...            kayak
# 1111  /content1/Automating_Port_Operations_dataset/f...       ferry_boat
# 2426  /content1/Automating_Port_Operations_dataset/g...          gondola
# 2567  /content1/Automating_Port_Operations_dataset/g...          gondola

# %%
duplicate_rows = new_img_df[new_img_df.duplicated(keep=False)]
duplicates_sorted = duplicate_rows.sort_values(by=new_img_df.columns.tolist())
pd.set_option('display.max_colwidth', 55)
print("\nAll duplicate rows, sorted to appear one below another:")
duplicates_sorted.head(10)
# Out:
# All duplicate rows, sorted to appear one below another:
#                                                   image_path label
# 1049  /content1/Automating_Port_Operations_dataset/buoy/1...  buoy
# 1177  /content1/Automating_Port_Operations_dataset/buoy/1...  buoy
# 1273  /content1/Automating_Port_Operations_dataset/buoy/1...  buoy
# 1368  /content1/Automating_Port_Operations_dataset/buoy/1...  buoy
# 1382  /content1/Automating_Port_Operations_dataset/buoy/1...  buoy
# 1404  /content1/Automating_Port_Operations_dataset/buoy/1...  buoy
# 1420  /content1/Automating_Port_Operations_dataset/buoy/1...  buoy
# 1442  /content1/Automating_Port_Operations_dataset/buoy/1...  buoy
# 1078  /content1/Automating_Port_Operations_dataset/buoy/1...  buoy
# 1212  /content1/Automating_Port_Operations_dataset/buoy/1...  buoy

# %%
new_img_df.iloc[46][0]
# Out:
# '/content1/Automating_Port_Operations_dataset/gondola/73.jpg'

# %%
train1_df, test_df = train_test_split(new_img_df, test_size=0.2, random_state=2)

# %%
train_df, val_df = train_test_split(train1_df, test_size=0.2, random_state=2)

# %%
len(train_df),len(test_df),len(val_df)
# Out:
# (2240, 701, 560)

# %%
train_generator = ImageDataGenerator(rescale=1./255,rotation_range=20,
                  width_shift_range=0.2,height_shift_range=0.2,
                  zoom_range=0.2,horizontal_flip=True,fill_mode='nearest')
test_generator = ImageDataGenerator(rescale=1./255)
val_generator = ImageDataGenerator(rescale=1./255)

# %%
train_generator ,test_generator
# Out:
# (<keras.src.preprocessing.image.ImageDataGenerator at 0x7f1215e14460>,
#  <keras.src.preprocessing.image.ImageDataGenerator at 0x7f1215e14a90>)

# %%
test_data = test_generator.flow_from_dataframe(
    test_df,
    x_col='image_path',
    y_col='label',
    target_size=(224, 224),
    class_mode='categorical',
    subset='training',
    shuffle=True,
    seed=28,
    color_mode='rgb'
)
# Out:
# Found 701 validated image filenames belonging to 9 classes.

# %%
train_data = train_generator.flow_from_dataframe(
    train_df,
    x_col='image_path',
    y_col='label',
    target_size=(224, 224),
    class_mode='categorical',
    subset='training',
    shuffle=True,
    seed=28,
    color_mode='rgb'
)
# Out:
# Found 2240 validated image filenames belonging to 9 classes.

# %%
val_data = val_generator.flow_from_dataframe(
    val_df,
    x_col='image_path',
    y_col='label',
    target_size=(224, 224),
    class_mode='categorical',
    subset='training',
    shuffle=True,
    seed=28,
    color_mode='rgb'
)
# Out:
# Found 560 validated image filenames belonging to 9 classes.

# %%
num_class = len(train_data.class_indices)
num_class
# Out:
# 9

# %%
def build_cnn_model(input_shape,num_class):
    model = Sequential()
    model.add(Conv2D(32, (3, 3), activation='relu', input_shape=input_shape))
    model.add(MaxPooling2D((2, 2)))
    model.add(Conv2D(64, (3, 3), activation='relu'))
    model.add(MaxPooling2D((2, 2)))
    model.add(Conv2D(128, (3, 3), activation='relu'))
    model.add(MaxPooling2D((2, 2)))
    model.add(GlobalAveragePooling2D())
    # model.add(Flatten())
    model.add(Dense(128, activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(128,activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(num_class, activation='softmax'))
    return model

input_shape = (224, 224, 3)
num_class = len(train_data.class_indices)
model_cnn = build_cnn_model(input_shape, num_class)

# %%
model_cnn.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
from tensorflow.keras.callbacks import EarlyStopping

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience=5,restore_best_weights=True)

# %%
model_cnn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 222, 222, 32)      896
#
#  max_pooling2d (MaxPooling2  (None, 111, 111, 32)      0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 109, 109, 64)      18496
#
#  max_pooling2d_1 (MaxPoolin  (None, 54, 54, 64)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 52, 52, 128)       73856
#
#  max_pooling2d_2 (MaxPoolin  (None, 26, 26, 128)       0
#  g2D)
#
#  global_average_pooling2d (  (None, 128)               0
#  GlobalAveragePooling2D)
#
#  dense (Dense)               (None, 128)               16512
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 128)               16512
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_2 (Dense)             (None, 9)                 1161
#
# =================================================================
# Total params: 127433 (497.79 KB)
# Trainable params: 127433 (497.79 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
history_cnn = model_cnn.fit(train_data, epochs=20, validation_data=val_data,callbacks=[early_stopping])
# Out:
# Epoch 1/20
# 70/70 [==============================] - 52s 630ms/step - loss: 2.1986 - accuracy: 0.1058 - val_loss: 2.1853 - val_accuracy: 0.1143
# Epoch 2/20
# 70/70 [==============================] - 46s 658ms/step - loss: 2.1636 - accuracy: 0.1545 - val_loss: 2.1242 - val_accuracy: 0.1875
# Epoch 3/20
# 70/70 [==============================] - 46s 658ms/step - loss: 2.1115 - accuracy: 0.2004 - val_loss: 2.0952 - val_accuracy: 0.1732
# Epoch 4/20
# 70/70 [==============================] - 44s 634ms/step - loss: 2.0899 - accuracy: 0.2036 - val_loss: 2.0663 - val_accuracy: 0.2179
# Epoch 5/20
# 70/70 [==============================] - 45s 640ms/step - loss: 2.0357 - accuracy: 0.2415 - val_loss: 2.0473 - val_accuracy: 0.2232
# Epoch 6/20
# 70/70 [==============================] - 44s 633ms/step - loss: 1.9827 - accuracy: 0.2714 - val_loss: 1.9352 - val_accuracy: 0.2464
# Epoch 7/20
# 70/70 [==============================] - 45s 644ms/step - loss: 1.9324 - accuracy: 0.2830 - val_loss: 2.0039 - val_accuracy: 0.2571
# Epoch 8/20
# 70/70 [==============================] - 44s 623ms/step - loss: 1.8826 - accuracy: 0.3094 - val_loss: 2.1723 - val_accuracy: 0.2250
# Epoch 9/20
# 70/70 [==============================] - 45s 644ms/step - loss: 1.8762 - accuracy: 0.3134 - val_loss: 1.8453 - val_accuracy: 0.3018
# Epoch 10/20
# 70/70 [==============================] - 46s 651ms/step - loss: 1.8109 - accuracy: 0.3464 - val_loss: 1.8486 - val_accuracy: 0.3250
# Epoch 11/20
# 70/70 [==============================] - 46s 663ms/step - loss: 1.7372 - accuracy: 0.3674 - val_loss: 2.0136 - val_accuracy: 0.2661
# Epoch 12/20
# 70/70 [==============================] - 46s 660ms/step - loss: 1.7218 - accuracy: 0.3808 - val_loss: 1.7009 - val_accuracy: 0.3643
# Epoch 13/20
# 70/70 [==============================] - 46s 657ms/step - loss: 1.6635 - accuracy: 0.4049 - val_loss: 1.7513 - val_accuracy: 0.3500
# Epoch 14/20
# 70/70 [==============================] - 45s 643ms/step - loss: 1.6251 - accuracy: 0.4219 - val_loss: 1.6224 - val_accuracy: 0.4036
# Epoch 15/20
# 70/70 [==============================] - 45s 648ms/step - loss: 1.5705 - accuracy: 0.4362 - val_loss: 1.6938 - val_accuracy: 0.3571
# Epoch 16/20
# 70/70 [==============================] - 45s 640ms/step - loss: 1.5420 - accuracy: 0.4563 - val_loss: 1.6901 - val_accuracy: 0.3786
# Epoch 17/20
# 70/70 [==============================] - 44s 631ms/step - loss: 1.5358 - accuracy: 0.4504 - val_loss: 1.5269 - val_accuracy: 0.4536
# Epoch 18/20
# 70/70 [==============================] - 43s 621ms/step - loss: 1.4401 - accuracy: 0.4835 - val_loss: 1.4796 - val_accuracy: 0.4732
# Epoch 19/20
# 70/70 [==============================] - 45s 642ms/step - loss: 1.3931 - accuracy: 0.5205 - val_loss: 1.4926 - val_accuracy: 0.4589
# Epoch 20/20
# 70/70 [==============================] - 44s 631ms/step - loss: 1.3929 - accuracy: 0.5129 - val_loss: 1.4714 - val_accuracy: 0.4357

# %%
test_loss, test_acc = model_cnn.evaluate(test_data)
print('Test Loss:', test_loss)
print('Test Accuracy:', test_acc)
# Out:
# 22/22 [==============================] - 5s 240ms/step - loss: 1.4458 - accuracy: 0.4650
# Test Loss: 1.445827603340149
# Test Accuracy: 0.4650499224662781

# %%
def plot_history(history):
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    epochs = range(1, len(acc) + 1)

    # Plot accuracy
    plt.figure(figsize=(12, 8))

    plt.subplot(1, 2, 1)
    plt.plot(epochs, acc, 'r', label='Training accuracy')
    plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
    plt.title('Training and validation accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()

    # Plot loss
    plt.subplot(1, 2, 2)
    plt.plot(epochs, loss, 'r', label='Training loss')
    plt.plot(epochs, val_loss, 'b', label='Validation loss')
    plt.title('Training and validation loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    plt.show()

# Call the plot_history function
plot_history(history_cnn)

# %%
predictions_cnn = model_cnn.predict(test_data)
predicted_labels_cnn = np.argmax(predictions_cnn, axis=1)

# Compute the confusion matrix
cm = confusion_matrix(test_data.classes, predicted_labels_cnn)
# Out:
# 22/22 [==============================] - 5s 208ms/step

# %%
predicted_labels_cnn
# Out:
# array([3, 8, 1, 0, 3, 4, 1, 5, 0, 7, 6, 7, 7, 7, 3, 6, 3, 8, 7, 3, 7, 7,
#        4, 4, 4, 3, 1, 4, 3, 3, 6, 4, 4, 6, 0, 7, 7, 7, 4, 1, 7, 4, 7, 5,
#        3, 7, 1, 7, 5, 1, 4, 4, 5, 4, 5, 6, 4, 4, 5, 1, 3, 1, 7, 7, 8, 7,
#        5, 0, 1, 6, 5, 3, 4, 5, 7, 3, 7, 3, 1, 1, 5, 5, 3, 7, 6, 5, 6, 1,
#        1, 4, 4, 1, 4, 7, 4, 1, 3, 8, 3, 3, 4, 1, 6, 5, 4, 1, 4, 7, 7, 7,
#        4, 5, 7, 1, 1, 0, 7, 4, 1, 7, 7, 2, 4, 4, 5, 1, 7, 7, 4, 4, 2, 0,
#        4, 8, 1, 7, 3, 3, 4, 4, 3, 3, 3, 1, 3, 8, 6, 4, 3, 1, 4, 7, 7, 4,
#        7, 1, 4, 3, 4, 1, 0, 1, 8, 5, 1, 1, 1, 1, 5, 7, 7, 3, 3, 3, 2, 1,
#        4, 3, 1, 4, 1, 1, 5, 3, 5, 1, 3, 4, 3, 1, 7, 4, 8, 1, 4, 4, 1, 3,
#        1, 4, 4, 4, 5, 4, 4, 7, 1, 1, 3, 1, 4, 5, 2, 4, 1, 1, 8, 3, 7, 1,
#        6, 8, 4, 2, 1, 7, 3, 3, 3, 4, 2, 0, 3, 5, 5, 7, 1, 2, 4, 4, 5, 3,
#        3, 5, 8, 5, 4, 3, 5, 7, 5, 4, 4, 4, 6, 3, 4, 7, 5, 1, 7, 3, 7, 3,
#        7, 4, 6, 1, 1, 4, 3, 4, 4, 3, 1, 8, 7, 5, 3, 3, 4, 4, 7, 7, 6, 5,
#        4, 1, 8, 4, 6, 1, 1, 4, 6, 3, 3, 3, 4, 5, 4, 4, 8, 8, 1, 6, 8, 1,
#        1, 0, 0, 1, 5, 8, 4, 1, 7, 3, 1, 8, 5, 4, 4, 2, 8, 3, 1, 3, 5, 4,
#        7, 3, 6, 3, 7, 4, 4, 5, 2, 1, 1, 5, 5, 4, 4, 8, 3, 7, 1, 4, 7, 4,
#        4, 8, 8, 4, 7, 4, 7, 5, 4, 4, 4, 3, 4, 1, 4, 5, 7, 8, 1, 6, 0, 1,
#        1, 7, 7, 7, 6, 5, 3, 1, 7, 4, 8, 3, 3, 3, 5, 8, 4, 5, 1, 1, 5, 8,
#        3, 4, 4, 7, 5, 7, 3, 3, 3, 3, 8, 4, 3, 4, 2, 1, 4, 6, 5, 1, 1, 1,
#        4, 4, 1, 4, 5, 6, 6, 3, 7, 8, 1, 5, 5, 6, 1, 4, 5, 0, 7, 4, 4, 8,
#        3, 1, 1, 8, 3, 6, 5, 1, 7, 4, 4, 7, 3, 4, 4, 5, 3, 5, 4, 4, 1, 7,
#        5, 1, 8, 1, 3, 4, 7, 2, 7, 1, 1, 1, 5, 6, 1, 3, 0, 4, 7, 4, 3, 4,
#        3, 3, 3, 2, 4, 1, 3, 4, 4, 4, 8, 4, 3, 5, 7, 3, 7, 1, 4, 1, 7, 6,
#        0, 7, 3, 3, 8, 1, 1, 4, 4, 3, 3, 3, 7, 1, 7, 1, 5, 3, 1, 3, 4, 7,
#        3, 4, 3, 5, 3, 8, 7, 5, 4, 7, 3, 3, 4, 7, 4, 7, 3, 4, 7, 3, 1, 1,
#        7, 4, 4, 1, 7, 1, 3, 1, 1, 1, 5, 7, 8, 3, 5, 8, 4, 3, 1, 5, 4, 7,
#        4, 7, 6, 1, 8, 1, 4, 5, 7, 7, 5, 4, 4, 5, 4, 5, 0, 3, 8, 1, 8, 1,
#        4, 8, 1, 4, 3, 7, 7, 3, 3, 1, 5, 2, 3, 1, 3, 8, 4, 1, 4, 1, 1, 1,
#        1, 3, 0, 1, 5, 0, 4, 3, 7, 8, 4, 3, 5, 1, 3, 3, 8, 7, 1, 7, 5, 3,
#        1, 8, 7, 7, 5, 2, 4, 3, 4, 1, 6, 4, 3, 3, 6, 1, 4, 4, 7, 8, 4, 1,
#        3, 4, 7, 4, 1, 7, 6, 3, 5, 5, 0, 1, 0, 3, 4, 3, 0, 8, 1, 3, 3, 8,
#        4, 5, 4, 4, 6, 6, 2, 4, 4, 1, 3, 1, 6, 7, 3, 5, 8, 3, 4])

# %%
# Plot the confusion matrix
def plot_confusion_matrix(cm, class_names):
    plt.figure(figsize=(16,8))
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names)
    disp.plot(cmap=plt.cm.Blues)
    plt.title('Confusion Matrix')
    xticks = plt.xticks(rotation=30)
    plt.show()

# %%
# Get the class names from the train dataset
class_names = train_data.class_indices.keys()
class_names
# Out:
# dict_keys(['buoy', 'cruise_ship', 'ferry_boat', 'freight_boat', 'gondola', 'inflatable_boat', 'kayak', 'paper_boat', 'sailboat'])

# %%
# Call the function to plot confusion matrix
plot_confusion_matrix(cm, class_names)

# %%
report_cnn = classification_report(test_data.classes,predicted_labels_cnn,target_names=class_names)
print("Classification Report:")
print(report_cnn)
# Out:
# Classification Report:
#                  precision    recall  f1-score   support
#
#            buoy       0.15      0.05      0.07        61
#     cruise_ship       0.14      0.26      0.18        68
#      ferry_boat       0.07      0.01      0.02        92
#    freight_boat       0.13      0.18      0.15        87
#         gondola       0.08      0.18      0.11        74
# inflatable_boat       0.13      0.12      0.13        82
#           kayak       0.09      0.04      0.06        75
#      paper_boat       0.13      0.14      0.13        93
#        sailboat       0.17      0.12      0.14        69
#
#        accuracy                           0.12       701
#       macro avg       0.12      0.12      0.11       701
#    weighted avg       0.12      0.12      0.11       701

# %%
from tensorflow.keras.applications import MobileNetV2

# %%
# Load MobileNet model without top layers
base_model = MobileNetV2(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Add new classification layers
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(1024, activation='relu')(x)
predictions_mv2 = Dense(num_class, activation='softmax')(x)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 [==============================] - 2s 0us/step

# %%
from tensorflow.keras.models import Model

# %%
# Combine base model with new classification layers
model1 = Model(inputs=base_model.input, outputs=predictions_mv2)

# Freeze base layers
for layer in base_model.layers:
    layer.trainable = False

# Compile the model
model1.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
early_stopping1 = EarlyStopping(monitor='val_loss', patience=5,restore_best_weights=True)

# %%
# Train the model
history1 = model1.fit(train_data, epochs=20, validation_data=val_data,callbacks=[early_stopping1])
# Out:
# Epoch 1/20
# 70/70 [==============================] - 52s 647ms/step - loss: 0.7420 - accuracy: 0.7571 - val_loss: 0.2847 - val_accuracy: 0.8857
# Epoch 2/20
# 70/70 [==============================] - 44s 636ms/step - loss: 0.2819 - accuracy: 0.9125 - val_loss: 0.2592 - val_accuracy: 0.9232
# Epoch 3/20
# 70/70 [==============================] - 45s 642ms/step - loss: 0.2366 - accuracy: 0.9205 - val_loss: 0.3243 - val_accuracy: 0.9000
# Epoch 4/20
# 70/70 [==============================] - 45s 646ms/step - loss: 0.1601 - accuracy: 0.9491 - val_loss: 0.2651 - val_accuracy: 0.9161
# Epoch 5/20
# 70/70 [==============================] - 45s 644ms/step - loss: 0.1195 - accuracy: 0.9571 - val_loss: 0.1951 - val_accuracy: 0.9393
# Epoch 6/20
# 70/70 [==============================] - 56s 805ms/step - loss: 0.0922 - accuracy: 0.9701 - val_loss: 0.2265 - val_accuracy: 0.9214
# Epoch 7/20
# 70/70 [==============================] - 43s 616ms/step - loss: 0.1136 - accuracy: 0.9612 - val_loss: 0.2424 - val_accuracy: 0.9321
# Epoch 8/20
# 70/70 [==============================] - 44s 627ms/step - loss: 0.0920 - accuracy: 0.9705 - val_loss: 0.1807 - val_accuracy: 0.9357
# Epoch 9/20
# 70/70 [==============================] - 44s 625ms/step - loss: 0.0574 - accuracy: 0.9799 - val_loss: 0.1995 - val_accuracy: 0.9411
# Epoch 10/20
# 70/70 [==============================] - 44s 635ms/step - loss: 0.1133 - accuracy: 0.9643 - val_loss: 0.1985 - val_accuracy: 0.9357
# Epoch 11/20
# 70/70 [==============================] - 44s 634ms/step - loss: 0.0880 - accuracy: 0.9714 - val_loss: 0.1188 - val_accuracy: 0.9643
# Epoch 12/20
# 70/70 [==============================] - 44s 631ms/step - loss: 0.0939 - accuracy: 0.9696 - val_loss: 0.2520 - val_accuracy: 0.9321
# Epoch 13/20
# 70/70 [==============================] - 44s 625ms/step - loss: 0.0793 - accuracy: 0.9754 - val_loss: 0.1477 - val_accuracy: 0.9571
# Epoch 14/20
# 70/70 [==============================] - 45s 637ms/step - loss: 0.0736 - accuracy: 0.9750 - val_loss: 0.1617 - val_accuracy: 0.9500
# Epoch 15/20
# 70/70 [==============================] - 43s 623ms/step - loss: 0.0460 - accuracy: 0.9857 - val_loss: 0.1661 - val_accuracy: 0.9411
# Epoch 16/20
# 70/70 [==============================] - 44s 623ms/step - loss: 0.0480 - accuracy: 0.9844 - val_loss: 0.1529 - val_accuracy: 0.9554

# %%
# Evaluate on test set
loss, accuracy = model1.evaluate(test_data)
print("Test Accuracy:", accuracy)
# Out:
# 22/22 [==============================] - 5s 245ms/step - loss: 0.1202 - accuracy: 0.9629
# Test Accuracy: 0.9629101157188416

# %%
plot_history(history1)

# %%
predictions1 = model1.predict(test_data)
# Out:
# 22/22 [==============================] - 7s 269ms/step

# %%
predicted_labels_mobilenet = np.argmax(predictions1, axis=1)

# %%
cm1 = confusion_matrix(test_data.classes,predicted_labels_mobilenet)

# %%
plot_confusion_matrix(cm1, class_names)

# %%
report_mobilenet = classification_report(test_data.classes, predicted_labels_mobilenet,target_names=class_names)
print("Classification Report:")
print(report_mobilenet)
# Out:
# Classification Report:
#                  precision    recall  f1-score   support
#
#            buoy       0.13      0.13      0.13        61
#     cruise_ship       0.10      0.10      0.10        68
#      ferry_boat       0.07      0.07      0.07        92
#    freight_boat       0.11      0.11      0.11        87
#         gondola       0.13      0.14      0.13        74
# inflatable_boat       0.10      0.10      0.10        82
#           kayak       0.11      0.11      0.11        75
#      paper_boat       0.12      0.12      0.12        93
#        sailboat       0.10      0.10      0.10        69
#
#        accuracy                           0.11       701
#       macro avg       0.11      0.11      0.11       701
#    weighted avg       0.11      0.11      0.11       701

# %%
img_1 = test_df.iloc[0]['image_path']

# %%
plt.imshow(cv2.imread(img_1))

# %%
from tensorflow.keras.applications.mobilenet import preprocess_input, decode_predictions

# %%
def load_and_preprocess_image(img_path):
    img = image.load_img(img_path, target_size=(224, 224))
    img_array = image.img_to_array(img)
    img_array = tf.expand_dims(img_array, 0)  # Create a batch
    return preprocess_input(img_array)

# %%
# Path to the image you want to predict
img_path = '/content1/Automating_Port_Operations_dataset/sailboat/1.jpg'

# Preprocess the image
preprocessed_img = load_and_preprocess_image(img_path)

# %%
# Predict using the model
predictions2 = model1.predict(preprocessed_img)

predicted_label = np.argmax(predictions2)
predicted_label
# Out:
# 1/1 [==============================] - 1s 1s/step
# 8

# %%
for class_name, class_idx in train_data.class_indices.items():
    if class_idx == predicted_label:
        predicted_class = class_name
        break
print(f'The identified object is : {class_name}')
# Out:
# The identified object is : sailboat

# %% [markdown]
# ### The object identified by MobilenetV2 is correct
# ### The Accuracy of the Model mabde by MobilenetV2 Viz model1 gives a value of 95% and also the computation time is less compared to Normal model

# %%
predictions3 = model_cnn.predict(preprocessed_img)
predicted_label3 = np.argmax(predictions3)
for class_name, class_idx in train_data.class_indices.items():
    if class_idx == predicted_label3:
        predicted_class = class_name
        break
print(f'The identified object is : {class_name}')
# Out:
# 1/1 [==============================] - 0s 191ms/step
# The identified object is : sailboat

# %% [markdown]
# ### The object identified by normal CNN model is incorrect
# ### The Accuraccy of thsi model viz 'model' works out to be 54.6%

# %% [markdown]
# ## MobilenetV2 is a very efficient and accurate image identifier model , THis can be easily loaded and used for varying application
# **bold text**

# %%
# Convert the model to TensorFlow Lite format
converter = tf.lite.TFLiteConverter.from_keras_model(model1)
tflite_model = converter.convert()

# Save the TensorFlow Lite model
with open('mobilnetaphsnr.tflite', 'wb') as f:
    f.write(tflite_model)
    print("TF Lite model saved successfully.")
# Out:
# TF Lite model saved successfully.

# %%
import os

def find_files_with_extension(extension, search_path):
    matches = []
    for root, dirs, files in os.walk(search_path):
        for file in files:
            if file.endswith(extension):
                matches.append(os.path.join(root, file))
    return matches

extension = '.tflite'
search_path = '/content'  # Root directory in Colab
files_found = find_files_with_extension(extension, search_path)

if files_found:
    print("Files found:")
    for file in files_found:
        print(file)
else:
    print("No files found with the extension", extension)
# Out:
# Files found:
# /content/mobilnetaphsnr.tflite

# %%
from PIL import Image

# %%
class_labels_new = {0: 'buoy',1:'cruise_ship',2:'ferry_boat',3:'freight_boat',4:'gondola',5:'inflatable_boat',6:'kayak',
                7:'paper_boat',8:'sailboat'}

# %%
interpreter = tf.lite.Interpreter(model_path='/content/mobilnetaphsnr.tflite')
interpreter.allocate_tensors()

# %%
img_new = Image.open('/content/pexels-padrinan-19678.jpg')

# %%
img_new = img_new.resize((224, 224))

# %%
img_arr_new = np.array(img_new)

# %%
img_arr_new = img_arr_new.astype('float32') / 255.0

# %%
input_data_new = np.expand_dims(img_arr_new, axis=0)

# %%
input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()

# %%
input_details,output_details
# Out:
# ([{'name': 'serving_default_input_1:0',
#    'index': 0,
#    'shape': array([  1, 224, 224,   3], dtype=int32),
#    'shape_signature': array([ -1, 224, 224,   3], dtype=int32),
#    'dtype': numpy.float32,
#    'quantization': (0.0, 0),
#    'quantization_parameters': {'scales': array([], dtype=float32),
#     'zero_points': array([], dtype=int32),
#     'quantized_dimension': 0},
#    'sparsity_parameters': {}}],
#  [{'name': 'StatefulPartitionedCall:0',
#    'index': 180,
#    'shape': array([1, 9], dtype=int32),
#    'shape_signature': array([-1,  9], dtype=int32),
#    'dtype': numpy.float32,
#    'quantization': (0.0, 0),
#    'quantization_parameters': {'scales': array([], dtype=float32),
#     'zero_points': array([], dtype=int32),
#     'quantized_dimension': 0},
#    'sparsity_parameters': {}}])

# %%
input_shape = input_details[0]['shape']
input_shape
# Out:
# array([  1, 224, 224,   3], dtype=int32)

# %%
interpreter.set_tensor(input_details[0]['index'], input_data_new)

# %%
interpreter.invoke()

# %%
output_data = interpreter.get_tensor(output_details[0]['index'])
print(f"Output Data : {output_data}")
# Out:
# Output Data : [[7.5962075e-06 3.1163730e-05 1.0251256e-07 1.1682314e-08 7.2018179e-07
#   5.8302402e-07 2.3288360e-06 9.9990499e-01 5.2597847e-05]]

# %%
predicted_class_new_indices = np.argmax(output_data, axis=1)

# %%
predicted_class_new_indices
# Out:
# array([7])

# %%
# Convert to class labels
predicted_class_labels = [class_labels[idx] for idx in predicted_class_new_indices]

print(f"Predicted class labels: {predicted_class_labels}")
# Out:
# Predicted class labels: ['paper_boat']

# %%
img_checked = cv2.imread('/content/pexels-padrinan-19678.jpg')
img_checked = cv2.cvtColor(img_checked, cv2.COLOR_BGR2RGB)
print(f"The image checked was :")
plt.imshow(img_checked)
# Out:
# The image checked was :
